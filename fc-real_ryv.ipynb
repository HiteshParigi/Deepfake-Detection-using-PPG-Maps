# %%
import cv2
import dlib
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from scipy import signal
from sklearn import preprocessing
import os
from PIL import Image
# Out:
# c:\Users\hites\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
outpath='E:/FF++/out_real_ryv'

# %%
def create_ppg_maps(vid_path,vid_num):
    
    # Define the input video file path
    video_path = vid_path

    # Open the video file
    cap = cv2.VideoCapture(video_path)

    # Get the frames per second (fps) and total frame count
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    # Set the desired number of frames per segment
    frames_per_segment = 128  # Set to 128 frames per segment

    detector = dlib.get_frontal_face_detector()
    predictor = dlib.shape_predictor("shape_predictor_68_face_landmarks/shape_predictor_68_face_landmarks (1).dat")  # You need to download this file
    # detector.set_min_detection_confidence(0.5)
    # Initialize variables to keep track of segment number and frames
    segment_number = 1
    frame_count = 0
    ppgmap=np.empty([128,32,3])
    ind=0

    while True:
        #print("hi")
        ret, frame = cap.read()
        if not ret:
            break
            
        frame=cv2.resize(frame,(854,480))
        
        # Convert the frame to grayscale for face detection
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        if(len(detector(gray))==0):
            continue

        face = detector(gray)[0]
        landmarks = predictor(gray, face)

        # Extract the coordinates of the nose (e.g., landmark point 30)
        nose_x = landmarks.part(30).x
        nose_y = landmarks.part(30).y

        # Define the ROI around the nose
        roi_size_width = 64
        roi_size_height = 32
        roi_x = nose_x - roi_size_width//2
        roi_y = nose_y - roi_size_height//2

        # Ensure ROI coordinates are within bounds
        roi_x = max(0, roi_x)
        roi_y = max(0, roi_y)
        roi_x_end = min(frame.shape[1], roi_x + roi_size_width)
        roi_y_end = min(frame.shape[0], roi_y + roi_size_height)

        # Extract the ROI
        roi = frame[roi_y:roi_y_end, roi_x:roi_x_end]
        
        # Calculate subregion size
        subregion_width = roi_size_width // 8  # 8 subregions horizontally
        subregion_height = roi_size_height // 4  # 4 subregions vertically

        subregions_r=np.zeros(32)
        subregions_y=np.zeros(32)
        subregions_v=np.zeros(32)
        k=0
        for i in range(4):
            for j in range(8):
                left = j * subregion_width
                upper = i * subregion_height
                right = (j + 1) * subregion_width
                lower = (i + 1) * subregion_height
                subregion=roi[upper:lower, left:right]

                roi_ycbcr = cv2.cvtColor(subregion, cv2.COLOR_BGR2YCrCb)
                roi_hsv = cv2.cvtColor(subregion, cv2.COLOR_BGR2HSV)
                
                y_comp = np.mean(roi_ycbcr[:, :, 0])  
                v_comp = np.mean(roi_hsv[:, :, 2])  
                rv=np.mean(subregion[:,:,0])
                
                subregions_r[k]=rv
                subregions_y[k]=y_comp
                subregions_v[k]=v_comp
                
                k+=1
                
        ppgmap[ind,:,0]=subregions_r
        ppgmap[ind,:,1]=subregions_y
        ppgmap[ind,:,2]=subregions_v
        #print(ppgmap[ind])
        ind+=1
        frame_count += 1
        #curr_seg.append(frame)
        #print(ppgmap[ind])
        if frame_count == frames_per_segment:
            vidnum=vid_num[:3]
            min_values = np.min(ppgmap, axis=(0, 1))
            max_values = np.max(ppgmap, axis=(0, 1))
            scaled_data = ((ppgmap - min_values) / (max_values - min_values) * 255.0).astype(np.uint8)
            cv2.imwrite(f'{outpath}/{vidnum}_{segment_number}.png',scaled_data)
            segment_number += 1
            ppgmap=np.empty([128,32,3])
            ind=0
            frame_count = 0
    cap.release()
    print(vid_path," completed.")

# %%
files=os.listdir('original_sequences/youtube/c23/videos')
# print(files)
count=1
for file in files:
    if(os.path.exists(f'out_real_ryv/{file[:3]}_1.png')):
        print('PPG already created', count)
        count+=1
        continue
    create_ppg_maps(f'original_sequences/youtube/c23/videos/{file}',file)
    print(count)
    count+=1
# Out:
# PPG already created 1
# PPG already created 2
# PPG already created 3
# PPG already created 4
# PPG already created 5
# PPG already created 6
# PPG already created 7
# PPG already created 8
# PPG already created 9
# PPG already created 10
# PPG already created 11
# PPG already created 12
# PPG already created 13
# PPG already created 14
# PPG already created 15
# PPG already created 16
# PPG already created 17
# PPG already created 18
# PPG already created 19
# PPG already created 20
# PPG already created 21
# PPG already created 22
# PPG already created 23
# PPG already created 24
# PPG already created 25
# PPG already created 26
# PPG already created 27
# PPG already created 28
# PPG already created 29
# PPG already created 30
# PPG already created 31
# PPG already created 32
# PPG already created 33
# PPG already created 34
# PPG already created 35
# PPG already created 36
# PPG already created 37
# PPG already created 38
# PPG already created 39
# PPG already created 40
# PPG already created 41
# PPG already created 42
# PPG already created 43
# PPG already created 44
# PPG already created 45
# PPG already created 46
# PPG already created 47
# PPG already created 48
# PPG already created 49
# PPG already created 50
# PPG already created 51
# PPG already created 52
# PPG already created 53
# PPG already created 54
# PPG already created 55
# PPG already created 56
# PPG already created 57
# PPG already created 58
# PPG already created 59
# PPG already created 60
# PPG already created 61
# PPG already created 62
# PPG already created 63
# PPG already created 64
# PPG already created 65
# PPG already created 66
# PPG already created 67
# PPG already created 68
# PPG already created 69
# PPG already created 70
# PPG already created 71
# PPG already created 72
# PPG already created 73
# PPG already created 74
# PPG already created 75
# PPG already created 76
# PPG already created 77
# PPG already created 78
# PPG already created 79
# PPG already created 80
# PPG already created 81
# PPG already created 82
# PPG already created 83
# PPG already created 84
# PPG already created 85
# PPG already created 86
# PPG already created 87
# PPG already created 88
# PPG already created 89
# PPG already created 90
# PPG already created 91
# PPG already created 92
# PPG already created 93
# PPG already created 94
# PPG already created 95
# PPG already created 96
# original_sequences/youtube/c23/videos/096.mp4  completed.
# 97
# PPG already created 98
# PPG already created 99
# PPG already created 100
# PPG already created 101
# PPG already created 102
# PPG already created 103
# PPG already created 104
# PPG already created 105
# PPG already created 106
# PPG already created 107
# PPG already created 108
# PPG already created 109
# PPG already created 110
# PPG already created 111
# PPG already created 112
# PPG already created 113
# PPG already created 114
# PPG already created 115
# PPG already created 116
# PPG already created 117
# PPG already created 118
# PPG already created 119
# PPG already created 120
# PPG already created 121
# PPG already created 122
# PPG already created 123
# PPG already created 124
# PPG already created 125
# PPG already created 126
# PPG already created 127
# PPG already created 128
# PPG already created 129
# PPG already created 130
# PPG already created 131
# PPG already created 132
# PPG already created 133
# PPG already created 134
# PPG already created 135
# PPG already created 136
# PPG already created 137
# PPG already created 138
# PPG already created 139
# PPG already created 140
# PPG already created 141
# PPG already created 142
# PPG already created 143
# PPG already created 144
# PPG already created 145
# PPG already created 146
# PPG already created 147
# PPG already created 148
# PPG already created 149
# PPG already created 150
# PPG already created 151
# PPG already created 152
# PPG already created 153
# PPG already created 154
# PPG already created 155
# PPG already created 156
# PPG already created 157
# PPG already created 158
# PPG already created 159
# PPG already created 160
# PPG already created 161
# PPG already created 162
# PPG already created 163
# PPG already created 164
# PPG already created 165
# PPG already created 166
# PPG already created 167
# PPG already created 168
# PPG already created 169
# PPG already created 170
# PPG already created 171
# PPG already created 172
# PPG already created 173
# PPG already created 174
# PPG already created 175
# PPG already created 176
# PPG already created 177
# PPG already created 178
# PPG already created 179
# PPG already created 180
# PPG already created 181
# PPG already created 182
# PPG already created 183
# PPG already created 184
# PPG already created 185
# PPG already created 186
# PPG already created 187
# PPG already created 188
# PPG already created 189
# PPG already created 190
# PPG already created 191
# PPG already created 192
# PPG already created 193
# PPG already created 194
# PPG already created 195
# PPG already created 196
# PPG already created 197
# PPG already created 198
# PPG already created 199
# PPG already created 200
# PPG already created 201
# PPG already created 202
# PPG already created 203
# PPG already created 204
# PPG already created 205
# PPG already created 206
# PPG already created 207
# PPG already created 208
# PPG already created 209
# PPG already created 210
# PPG already created 211
# PPG already created 212
# PPG already created 213
# PPG already created 214
# PPG already created 215
# PPG already created 216
# PPG already created 217
# PPG already created 218
# PPG already created 219
# PPG already created 220
# PPG already created 221
# PPG already created 222
# PPG already created 223
# PPG already created 224
# PPG already created 225
# PPG already created 226
# PPG already created 227
# PPG already created 228
# PPG already created 229
# PPG already created 230
# PPG already created 231
# PPG already created 232
# PPG already created 233
# PPG already created 234
# PPG already created 235
# PPG already created 236
# PPG already created 237
# PPG already created 238
# PPG already created 239
# PPG already created 240
# PPG already created 241
# PPG already created 242
# PPG already created 243
# PPG already created 244
# PPG already created 245
# PPG already created 246
# PPG already created 247
# PPG already created 248
# PPG already created 249
# PPG already created 250
# PPG already created 251
# PPG already created 252
# PPG already created 253
# PPG already created 254
# PPG already created 255
# PPG already created 256
# PPG already created 257
# PPG already created 258
# PPG already created 259
# PPG already created 260
# PPG already created 261
# PPG already created 262
# PPG already created 263
# PPG already created 264
# PPG already created 265
# PPG already created 266
# PPG already created 267
# PPG already created 268
# PPG already created 269
# PPG already created 270
# PPG already created 271
# PPG already created 272
# PPG already created 273
# PPG already created 274
# PPG already created 275
# PPG already created 276
# PPG already created 277
# PPG already created 278
# PPG already created 279
# PPG already created 280
# PPG already created 281
# PPG already created 282
# PPG already created 283
# PPG already created 284
# PPG already created 285
# PPG already created 286
# PPG already created 287
# PPG already created 288
# PPG already created 289
# PPG already created 290
# PPG already created 291
# PPG already created 292
# PPG already created 293
# PPG already created 294
# PPG already created 295
# PPG already created 296
# PPG already created 297
# PPG already created 298
# PPG already created 299
# PPG already created 300
# PPG already created 301
# PPG already created 302
# PPG already created 303
# PPG already created 304
# PPG already created 305
# PPG already created 306
# PPG already created 307
# PPG already created 308
# PPG already created 309
# PPG already created 310
# PPG already created 311
# PPG already created 312
# PPG already created 313
# PPG already created 314
# PPG already created 315
# PPG already created 316
# PPG already created 317
# PPG already created 318
# PPG already created 319
# PPG already created 320
# PPG already created 321
# PPG already created 322
# PPG already created 323
# PPG already created 324
# PPG already created 325
# PPG already created 326
# PPG already created 327
# PPG already created 328
# PPG already created 329
# PPG already created 330
# PPG already created 331
# PPG already created 332
# PPG already created 333
# PPG already created 334
# PPG already created 335
# PPG already created 336
# PPG already created 337
# PPG already created 338
# PPG already created 339
# PPG already created 340
# PPG already created 341
# PPG already created 342
# PPG already created 343
# PPG already created 344
# PPG already created 345
# PPG already created 346
# PPG already created 347
# PPG already created 348
# PPG already created 349
# PPG already created 350
# PPG already created 351
# PPG already created 352
# PPG already created 353
# PPG already created 354
# PPG already created 355
# PPG already created 356
# PPG already created 357
# PPG already created 358
# PPG already created 359
# PPG already created 360
# PPG already created 361
# PPG already created 362
# PPG already created 363
# PPG already created 364
# PPG already created 365
# PPG already created 366
# PPG already created 367
# PPG already created 368
# PPG already created 369
# PPG already created 370
# PPG already created 371
# PPG already created 372
# PPG already created 373
# PPG already created 374
# PPG already created 375
# PPG already created 376
# PPG already created 377
# PPG already created 378
# PPG already created 379
# PPG already created 380
# PPG already created 381
# PPG already created 382
# PPG already created 383
# PPG already created 384
# PPG already created 385
# PPG already created 386
# PPG already created 387
# PPG already created 388
# PPG already created 389
# PPG already created 390
# PPG already created 391
# PPG already created 392
# PPG already created 393
# PPG already created 394
# PPG already created 395
# PPG already created 396
# PPG already created 397
# PPG already created 398
# PPG already created 399
# PPG already created 400
# PPG already created 401
# PPG already created 402
# PPG already created 403
# original_sequences/youtube/c23/videos/403.mp4  completed.
# 404
# PPG already created 405
# PPG already created 406
# PPG already created 407
# PPG already created 408
# PPG already created 409
# PPG already created 410
# PPG already created 411
# PPG already created 412
# PPG already created 413
# PPG already created 414
# PPG already created 415
# PPG already created 416
# PPG already created 417
# PPG already created 418
# PPG already created 419
# PPG already created 420
# PPG already created 421
# PPG already created 422
# PPG already created 423
# PPG already created 424
# PPG already created 425
# PPG already created 426
# PPG already created 427
# PPG already created 428
# PPG already created 429
# PPG already created 430
# PPG already created 431
# PPG already created 432
# PPG already created 433
# PPG already created 434
# PPG already created 435
# PPG already created 436
# PPG already created 437
# PPG already created 438
# PPG already created 439
# PPG already created 440
# PPG already created 441
# PPG already created 442
# PPG already created 443
# PPG already created 444
# PPG already created 445
# PPG already created 446
# PPG already created 447
# PPG already created 448
# PPG already created 449
# PPG already created 450
# PPG already created 451
# PPG already created 452
# PPG already created 453
# PPG already created 454
# PPG already created 455
# PPG already created 456
# PPG already created 457
# PPG already created 458
# PPG already created 459
# PPG already created 460
# PPG already created 461
# PPG already created 462
# PPG already created 463
# PPG already created 464
# PPG already created 465
# PPG already created 466
# PPG already created 467
# PPG already created 468
# PPG already created 469
# PPG already created 470
# PPG already created 471
# PPG already created 472
# PPG already created 473
# PPG already created 474
# PPG already created 475
# PPG already created 476
# PPG already created 477
# PPG already created 478
# PPG already created 479
# PPG already created 480
# PPG already created 481
# PPG already created 482
# PPG already created 483
# PPG already created 484
# PPG already created 485
# PPG already created 486
# PPG already created 487
# PPG already created 488
# PPG already created 489
# PPG already created 490
# PPG already created 491
# PPG already created 492
# PPG already created 493
# PPG already created 494
# PPG already created 495
# PPG already created 496
# PPG already created 497
# PPG already created 498
# PPG already created 499
# PPG already created 500
# PPG already created 501
# PPG already created 502
# PPG already created 503
# PPG already created 504
# PPG already created 505
# PPG already created 506
# PPG already created 507
# PPG already created 508
# PPG already created 509
# PPG already created 510
# PPG already created 511
# PPG already created 512
# PPG already created 513
# PPG already created 514
# PPG already created 515
# PPG already created 516
# PPG already created 517
# PPG already created 518
# PPG already created 519
# PPG already created 520
# PPG already created 521
# PPG already created 522
# PPG already created 523
# PPG already created 524
# PPG already created 525
# PPG already created 526
# PPG already created 527
# PPG already created 528
# PPG already created 529
# PPG already created 530
# PPG already created 531
# PPG already created 532
# PPG already created 533
# PPG already created 534
# PPG already created 535
# PPG already created 536
# PPG already created 537
# PPG already created 538
# PPG already created 539
# PPG already created 540
# PPG already created 541
# PPG already created 542
# PPG already created 543
# PPG already created 544
# PPG already created 545
# PPG already created 546
# PPG already created 547
# PPG already created 548
# PPG already created 549
# PPG already created 550
# PPG already created 551
# PPG already created 552
# PPG already created 553
# PPG already created 554
# PPG already created 555
# PPG already created 556
# PPG already created 557
# PPG already created 558
# PPG already created 559
# PPG already created 560
# PPG already created 561
# PPG already created 562
# PPG already created 563
# PPG already created 564
# PPG already created 565
# PPG already created 566
# PPG already created 567
# PPG already created 568
# PPG already created 569
# PPG already created 570
# PPG already created 571
# PPG already created 572
# PPG already created 573
# PPG already created 574
# PPG already created 575
# PPG already created 576
# PPG already created 577
# PPG already created 578
# PPG already created 579
# PPG already created 580
# PPG already created 581
# PPG already created 582
# PPG already created 583
# PPG already created 584
# PPG already created 585
# PPG already created 586
# PPG already created 587
# PPG already created 588
# PPG already created 589
# PPG already created 590
# PPG already created 591
# PPG already created 592
# PPG already created 593
# PPG already created 594
# PPG already created 595
# PPG already created 596
# PPG already created 597
# PPG already created 598
# PPG already created 599
# PPG already created 600
# PPG already created 601
# PPG already created 602
# PPG already created 603
# PPG already created 604
# PPG already created 605
# PPG already created 606
# PPG already created 607
# PPG already created 608
# PPG already created 609
# PPG already created 610
# PPG already created 611
# PPG already created 612
# PPG already created 613
# PPG already created 614
# PPG already created 615
# PPG already created 616
# PPG already created 617
# PPG already created 618
# PPG already created 619
# PPG already created 620
# PPG already created 621
# PPG already created 622
# PPG already created 623
# PPG already created 624
# PPG already created 625
# PPG already created 626
# PPG already created 627
# PPG already created 628
# PPG already created 629
# PPG already created 630
# PPG already created 631
# PPG already created 632
# PPG already created 633
# PPG already created 634
# PPG already created 635
# PPG already created 636
# PPG already created 637
# PPG already created 638
# PPG already created 639
# PPG already created 640
# PPG already created 641
# PPG already created 642
# PPG already created 643
# PPG already created 644
# PPG already created 645
# PPG already created 646
# PPG already created 647
# PPG already created 648
# PPG already created 649
# PPG already created 650
# PPG already created 651
# PPG already created 652
# PPG already created 653
# PPG already created 654
# PPG already created 655
# PPG already created 656
# PPG already created 657
# PPG already created 658
# PPG already created 659
# PPG already created 660
# PPG already created 661
# PPG already created 662
# PPG already created 663
# PPG already created 664
# PPG already created 665
# PPG already created 666
# PPG already created 667
# PPG already created 668
# PPG already created 669
# PPG already created 670
# PPG already created 671
# PPG already created 672
# PPG already created 673
# PPG already created 674
# PPG already created 675
# PPG already created 676
# PPG already created 677
# PPG already created 678
# PPG already created 679
# PPG already created 680
# PPG already created 681
# PPG already created 682
# PPG already created 683
# PPG already created 684
# PPG already created 685
# PPG already created 686
# PPG already created 687
# PPG already created 688
# PPG already created 689
# PPG already created 690
# PPG already created 691
# PPG already created 692
# PPG already created 693
# PPG already created 694
# PPG already created 695
# PPG already created 696
# PPG already created 697
# PPG already created 698
# PPG already created 699
# PPG already created 700
# PPG already created 701
# PPG already created 702
# PPG already created 703
# PPG already created 704
# PPG already created 705
# PPG already created 706
# PPG already created 707
# PPG already created 708
# PPG already created 709
# PPG already created 710
# PPG already created 711
# PPG already created 712
# PPG already created 713
# PPG already created 714
# PPG already created 715
# PPG already created 716
# PPG already created 717
# PPG already created 718
# PPG already created 719
# PPG already created 720
# PPG already created 721
# PPG already created 722
# PPG already created 723
# PPG already created 724
# PPG already created 725
# PPG already created 726
# PPG already created 727
# PPG already created 728
# PPG already created 729
# PPG already created 730
# PPG already created 731
# PPG already created 732
# PPG already created 733
# PPG already created 734
# PPG already created 735
# PPG already created 736
# PPG already created 737
# PPG already created 738
# PPG already created 739
# PPG already created 740
# PPG already created 741
# PPG already created 742
# PPG already created 743
# PPG already created 744
# PPG already created 745
# PPG already created 746
# PPG already created 747
# PPG already created 748
# PPG already created 749
# PPG already created 750
# PPG already created 751
# PPG already created 752
# PPG already created 753
# PPG already created 754
# PPG already created 755
# PPG already created 756
# PPG already created 757
# PPG already created 758
# PPG already created 759
# PPG already created 760
# PPG already created 761
# PPG already created 762
# PPG already created 763
# PPG already created 764
# PPG already created 765
# PPG already created 766
# PPG already created 767
# PPG already created 768
# PPG already created 769
# PPG already created 770
# PPG already created 771
# PPG already created 772
# PPG already created 773
# PPG already created 774
# PPG already created 775
# PPG already created 776
# PPG already created 777
# PPG already created 778
# PPG already created 779
# PPG already created 780
# PPG already created 781
# PPG already created 782
# PPG already created 783
# PPG already created 784
# PPG already created 785
# PPG already created 786
# PPG already created 787
# PPG already created 788
# PPG already created 789
# PPG already created 790
# PPG already created 791
# PPG already created 792
# PPG already created 793
# PPG already created 794
# PPG already created 795
# PPG already created 796
# PPG already created 797
# PPG already created 798
# PPG already created 799
# PPG already created 800
# PPG already created 801
# PPG already created 802
# PPG already created 803
# PPG already created 804
# PPG already created 805
# PPG already created 806
# PPG already created 807
# PPG already created 808
# PPG already created 809
# PPG already created 810
# PPG already created 811
# PPG already created 812
# PPG already created 813
# PPG already created 814
# PPG already created 815
# PPG already created 816
# PPG already created 817
# PPG already created 818
# PPG already created 819
# PPG already created 820
# PPG already created 821
# PPG already created 822
# PPG already created 823
# PPG already created 824
# PPG already created 825
# PPG already created 826
# PPG already created 827
# PPG already created 828
# PPG already created 829
# PPG already created 830
# PPG already created 831
# PPG already created 832
# PPG already created 833
# original_sequences/youtube/c23/videos/833.mp4  completed.
# 834
# original_sequences/youtube/c23/videos/834.mp4  completed.
# 835
# original_sequences/youtube/c23/videos/835.mp4  completed.
# 836
# original_sequences/youtube/c23/videos/836.mp4  completed.
# 837
# original_sequences/youtube/c23/videos/837.mp4  completed.
# 838
# original_sequences/youtube/c23/videos/838.mp4  completed.
# 839
# original_sequences/youtube/c23/videos/839.mp4  completed.
# 840
# original_sequences/youtube/c23/videos/840.mp4  completed.
# 841
# original_sequences/youtube/c23/videos/841.mp4  completed.
# 842
# original_sequences/youtube/c23/videos/842.mp4  completed.
# 843
# original_sequences/youtube/c23/videos/843.mp4  completed.
# 844
# original_sequences/youtube/c23/videos/844.mp4  completed.
# 845
# original_sequences/youtube/c23/videos/845.mp4  completed.
# 846
# original_sequences/youtube/c23/videos/846.mp4  completed.
# 847
# original_sequences/youtube/c23/videos/847.mp4  completed.
# 848
# original_sequences/youtube/c23/videos/848.mp4  completed.
# 849
# original_sequences/youtube/c23/videos/849.mp4  completed.
# 850
# original_sequences/youtube/c23/videos/850.mp4  completed.
# 851
# original_sequences/youtube/c23/videos/851.mp4  completed.
# 852
# original_sequences/youtube/c23/videos/852.mp4  completed.
# 853
# original_sequences/youtube/c23/videos/853.mp4  completed.
# 854
# original_sequences/youtube/c23/videos/854.mp4  completed.
# 855
# original_sequences/youtube/c23/videos/855.mp4  completed.
# 856
# original_sequences/youtube/c23/videos/856.mp4  completed.
# 857
# original_sequences/youtube/c23/videos/857.mp4  completed.
# 858
# original_sequences/youtube/c23/videos/858.mp4  completed.
# 859
# original_sequences/youtube/c23/videos/859.mp4  completed.
# 860
# original_sequences/youtube/c23/videos/860.mp4  completed.
# 861
# original_sequences/youtube/c23/videos/861.mp4  completed.
# 862
# original_sequences/youtube/c23/videos/862.mp4  completed.
# 863
# original_sequences/youtube/c23/videos/863.mp4  completed.
# 864
# original_sequences/youtube/c23/videos/864.mp4  completed.
# 865
# original_sequences/youtube/c23/videos/865.mp4  completed.
# 866
# original_sequences/youtube/c23/videos/866.mp4  completed.
# 867
# original_sequences/youtube/c23/videos/867.mp4  completed.
# 868
# original_sequences/youtube/c23/videos/868.mp4  completed.
# 869
# original_sequences/youtube/c23/videos/869.mp4  completed.
# 870
# original_sequences/youtube/c23/videos/870.mp4  completed.
# 871
# original_sequences/youtube/c23/videos/871.mp4  completed.
# 872
# original_sequences/youtube/c23/videos/872.mp4  completed.
# 873
# original_sequences/youtube/c23/videos/873.mp4  completed.
# 874
# original_sequences/youtube/c23/videos/874.mp4  completed.
# 875
# original_sequences/youtube/c23/videos/875.mp4  completed.
# 876
# original_sequences/youtube/c23/videos/876.mp4  completed.
# 877
# original_sequences/youtube/c23/videos/877.mp4  completed.
# 878
# original_sequences/youtube/c23/videos/878.mp4  completed.
# 879
# original_sequences/youtube/c23/videos/879.mp4  completed.
# 880
# original_sequences/youtube/c23/videos/880.mp4  completed.
# 881
# original_sequences/youtube/c23/videos/881.mp4  completed.
# 882
# original_sequences/youtube/c23/videos/882.mp4  completed.
# 883
# original_sequences/youtube/c23/videos/883.mp4  completed.
# 884
# original_sequences/youtube/c23/videos/884.mp4  completed.
# 885
# original_sequences/youtube/c23/videos/885.mp4  completed.
# 886
# original_sequences/youtube/c23/videos/886.mp4  completed.
# 887
# original_sequences/youtube/c23/videos/887.mp4  completed.
# 888
# original_sequences/youtube/c23/videos/888.mp4  completed.
# 889
# original_sequences/youtube/c23/videos/889.mp4  completed.
# 890
# original_sequences/youtube/c23/videos/890.mp4  completed.
# 891
# original_sequences/youtube/c23/videos/891.mp4  completed.
# 892
# original_sequences/youtube/c23/videos/892.mp4  completed.
# 893
# original_sequences/youtube/c23/videos/893.mp4  completed.
# 894
# original_sequences/youtube/c23/videos/894.mp4  completed.
# 895
# original_sequences/youtube/c23/videos/895.mp4  completed.
# 896
# original_sequences/youtube/c23/videos/896.mp4  completed.
# 897
# original_sequences/youtube/c23/videos/897.mp4  completed.
# 898
# original_sequences/youtube/c23/videos/898.mp4  completed.
# 899
# original_sequences/youtube/c23/videos/899.mp4  completed.
# 900
# original_sequences/youtube/c23/videos/900.mp4  completed.
# 901
# original_sequences/youtube/c23/videos/901.mp4  completed.
# 902
# original_sequences/youtube/c23/videos/902.mp4  completed.
# 903
# original_sequences/youtube/c23/videos/903.mp4  completed.
# 904
# original_sequences/youtube/c23/videos/904.mp4  completed.
# 905
# original_sequences/youtube/c23/videos/905.mp4  completed.
# 906
# original_sequences/youtube/c23/videos/906.mp4  completed.
# 907
# original_sequences/youtube/c23/videos/907.mp4  completed.
# 908
# original_sequences/youtube/c23/videos/908.mp4  completed.
# 909
# original_sequences/youtube/c23/videos/909.mp4  completed.
# 910
# original_sequences/youtube/c23/videos/910.mp4  completed.
# 911
# original_sequences/youtube/c23/videos/911.mp4  completed.
# 912
# original_sequences/youtube/c23/videos/912.mp4  completed.
# 913
# original_sequences/youtube/c23/videos/913.mp4  completed.
# 914
# original_sequences/youtube/c23/videos/914.mp4  completed.
# 915
# original_sequences/youtube/c23/videos/915.mp4  completed.
# 916
# original_sequences/youtube/c23/videos/916.mp4  completed.
# 917
# original_sequences/youtube/c23/videos/917.mp4  completed.
# 918
# original_sequences/youtube/c23/videos/918.mp4  completed.
# 919
# original_sequences/youtube/c23/videos/919.mp4  completed.
# 920
# original_sequences/youtube/c23/videos/920.mp4  completed.
# 921
# original_sequences/youtube/c23/videos/921.mp4  completed.
# 922
# original_sequences/youtube/c23/videos/922.mp4  completed.
# 923
# original_sequences/youtube/c23/videos/923.mp4  completed.
# 924
# original_sequences/youtube/c23/videos/924.mp4  completed.
# 925
# original_sequences/youtube/c23/videos/925.mp4  completed.
# 926
# original_sequences/youtube/c23/videos/926.mp4  completed.
# 927
# original_sequences/youtube/c23/videos/927.mp4  completed.
# 928
# original_sequences/youtube/c23/videos/928.mp4  completed.
# 929
# original_sequences/youtube/c23/videos/929.mp4  completed.
# 930
# original_sequences/youtube/c23/videos/930.mp4  completed.
# 931
# original_sequences/youtube/c23/videos/931.mp4  completed.
# 932
# original_sequences/youtube/c23/videos/932.mp4  completed.
# 933
# original_sequences/youtube/c23/videos/933.mp4  completed.
# 934
# original_sequences/youtube/c23/videos/934.mp4  completed.
# 935
# original_sequences/youtube/c23/videos/935.mp4  completed.
# 936
# original_sequences/youtube/c23/videos/936.mp4  completed.
# 937
# original_sequences/youtube/c23/videos/937.mp4  completed.
# 938
# original_sequences/youtube/c23/videos/938.mp4  completed.
# 939
# original_sequences/youtube/c23/videos/939.mp4  completed.
# 940
# original_sequences/youtube/c23/videos/940.mp4  completed.
# 941
# original_sequences/youtube/c23/videos/941.mp4  completed.
# 942
# original_sequences/youtube/c23/videos/942.mp4  completed.
# 943
# original_sequences/youtube/c23/videos/943.mp4  completed.
# 944
# original_sequences/youtube/c23/videos/944.mp4  completed.
# 945
# original_sequences/youtube/c23/videos/945.mp4  completed.
# 946
# original_sequences/youtube/c23/videos/946.mp4  completed.
# 947
# original_sequences/youtube/c23/videos/947.mp4  completed.
# 948
# original_sequences/youtube/c23/videos/948.mp4  completed.
# 949
# original_sequences/youtube/c23/videos/949.mp4  completed.
# 950
# original_sequences/youtube/c23/videos/950.mp4  completed.
# 951
# original_sequences/youtube/c23/videos/951.mp4  completed.
# 952
# original_sequences/youtube/c23/videos/952.mp4  completed.
# 953
# original_sequences/youtube/c23/videos/953.mp4  completed.
# 954
# original_sequences/youtube/c23/videos/954.mp4  completed.
# 955
# original_sequences/youtube/c23/videos/955.mp4  completed.
# 956
# original_sequences/youtube/c23/videos/956.mp4  completed.
# 957
# original_sequences/youtube/c23/videos/957.mp4  completed.
# 958
# original_sequences/youtube/c23/videos/958.mp4  completed.
# 959
# original_sequences/youtube/c23/videos/959.mp4  completed.
# 960
# original_sequences/youtube/c23/videos/960.mp4  completed.
# 961
# original_sequences/youtube/c23/videos/961.mp4  completed.
# 962
# original_sequences/youtube/c23/videos/962.mp4  completed.
# 963
# original_sequences/youtube/c23/videos/963.mp4  completed.
# 964
# original_sequences/youtube/c23/videos/964.mp4  completed.
# 965
# original_sequences/youtube/c23/videos/965.mp4  completed.
# 966
# original_sequences/youtube/c23/videos/966.mp4  completed.
# 967
# original_sequences/youtube/c23/videos/967.mp4  completed.
# 968
# original_sequences/youtube/c23/videos/968.mp4  completed.
# 969
# original_sequences/youtube/c23/videos/969.mp4  completed.
# 970
# original_sequences/youtube/c23/videos/970.mp4  completed.
# 971
# original_sequences/youtube/c23/videos/971.mp4  completed.
# 972
# original_sequences/youtube/c23/videos/972.mp4  completed.
# 973
# original_sequences/youtube/c23/videos/973.mp4  completed.
# 974
# original_sequences/youtube/c23/videos/974.mp4  completed.
# 975
# original_sequences/youtube/c23/videos/975.mp4  completed.
# 976
# original_sequences/youtube/c23/videos/976.mp4  completed.
# 977
# original_sequences/youtube/c23/videos/977.mp4  completed.
# 978
# original_sequences/youtube/c23/videos/978.mp4  completed.
# 979
# original_sequences/youtube/c23/videos/979.mp4  completed.
# 980
# original_sequences/youtube/c23/videos/980.mp4  completed.
# 981
# original_sequences/youtube/c23/videos/981.mp4  completed.
# 982
# original_sequences/youtube/c23/videos/982.mp4  completed.
# 983
# original_sequences/youtube/c23/videos/983.mp4  completed.
# 984
# original_sequences/youtube/c23/videos/984.mp4  completed.
# 985
# original_sequences/youtube/c23/videos/985.mp4  completed.
# 986
# original_sequences/youtube/c23/videos/986.mp4  completed.
# 987
# original_sequences/youtube/c23/videos/987.mp4  completed.
# 988
# original_sequences/youtube/c23/videos/988.mp4  completed.
# 989
# original_sequences/youtube/c23/videos/989.mp4  completed.
# 990
# original_sequences/youtube/c23/videos/990.mp4  completed.
# 991
# original_sequences/youtube/c23/videos/991.mp4  completed.
# 992
# original_sequences/youtube/c23/videos/992.mp4  completed.
# 993
# original_sequences/youtube/c23/videos/993.mp4  completed.
# 994
# original_sequences/youtube/c23/videos/994.mp4  completed.
# 995
# original_sequences/youtube/c23/videos/995.mp4  completed.
# 996
# original_sequences/youtube/c23/videos/996.mp4  completed.
# 997
# original_sequences/youtube/c23/videos/997.mp4  completed.
# 998
# original_sequences/youtube/c23/videos/998.mp4  completed.
# 999
# original_sequences/youtube/c23/videos/999.mp4  completed.
# 1000

# %%
# def create_ppg_maps(vid_path,vid_num):
    
#     # Define the input video file path
#     video_path = vid_path

#     # Open the video file
#     cap = cv2.VideoCapture(video_path)

#     # Get the frames per second (fps) and total frame count
#     fps = int(cap.get(cv2.CAP_PROP_FPS))
#     total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
#     # Set the desired number of frames per segment
#     frames_per_segment = 128  # Set to 128 frames per segment

#     detector = dlib.get_frontal_face_detector()
#     predictor = dlib.shape_predictor("shape_predictor_68_face_landmarks/shape_predictor_68_face_landmarks (1).dat")  # You need to download this file
#     # detector.set_min_detection_confidence(0.5)
#     # Initialize variables to keep track of segment number and frames
#     segment_number = 1
#     frame_count = 0
#     ppgmap=np.empty([128,32,5])
#     ind=0
#     gabor_kernel = cv2.getGaborKernel((3, 3), 1, 0, 1, 0.5, 0)

#     while True:
#         #print("hi")
#         ret, frame = cap.read()
#         if not ret:
#             break
            
#         frame=cv2.resize(frame,(854,480))
        
#         # Convert the frame to grayscale for face detection
#         gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

#         if(len(detector(gray))==0):
#             continue

#         face = detector(gray)[0]
#         landmarks = predictor(gray, face)

#         # Extract the coordinates of the nose (e.g., landmark point 30)
#         nose_x = landmarks.part(30).x
#         nose_y = landmarks.part(30).y

#         # Define the ROI around the nose
#         roi_size_width = 64
#         roi_size_height = 32
#         roi_x = nose_x - roi_size_width//2
#         roi_y = nose_y - roi_size_height//2

#         # Ensure ROI coordinates are within bounds
#         roi_x = max(0, roi_x)
#         roi_y = max(0, roi_y)
#         roi_x_end = min(frame.shape[1], roi_x + roi_size_width)
#         roi_y_end = min(frame.shape[0], roi_y + roi_size_height)

#         # Extract the ROI
#         roi = frame[roi_y:roi_y_end, roi_x:roi_x_end]
        
#         # Calculate subregion size
#         subregion_width = roi_size_width // 8  # 8 subregions horizontally
#         subregion_height = roi_size_height // 4  # 4 subregions vertically

#         subregions_r=np.zeros(32)
#         subregions_y=np.zeros(32)
#         subregions_v=np.zeros(32)
#         subregions_b=np.zeros(32)
#         subregions_g=np.zeros(32)
#         k=0
#         for i in range(4):
#             for j in range(8):
#                 left = j * subregion_width
#                 upper = i * subregion_height
#                 right = (j + 1) * subregion_width
#                 lower = (i + 1) * subregion_height
#                 subregion=roi[upper:lower, left:right]

#                 roi_ycbcr = cv2.cvtColor(subregion, cv2.COLOR_BGR2YCrCb)
#                 roi_hsv=cv2.cvtColor(subregion, cv2.COLOR_BGR2HSV)
                
#                 y_layer=roi_ycbcr[:, :, 0]
#                 v_layer=roi_hsv[:, :, 2]
#                 r_layer=subregion[:,:,0]
#                 b_layer=subregion[:,:,1]
#                 g_layer=subregion[:,:,2]
                
#                 print(y_layer.shape)
#                 y_layer = cv2.filter2D(y_layer, cv2.CV_32F, gabor_kernel)
#                 v_layer = cv2.filter2D(v_layer, cv2.CV_32F, gabor_kernel)
#                 r_layer = cv2.filter2D(r_layer, cv2.CV_32F, gabor_kernel)
#                 b_layer = cv2.filter2D(b_layer, cv2.CV_32F, gabor_kernel)
#                 g_layer = cv2.filter2D(g_layer, cv2.CV_32F, gabor_kernel)
#                 print(y_layer.shape)
#                 print()
#                 y_comp = np.mean(y_layer)  
#                 v_comp = np.mean(v_layer)  
#                 rv=np.mean(r_layer)
#                 bv=np.mean(b_layer)
#                 gv=np.mean(g_layer)
                
#                 subregions_r[k]=rv
#                 subregions_b[k]=bv
#                 subregions_g[k]=gv
#                 subregions_y[k]=y_comp
#                 subregions_v[k]=v_comp
#                 k+=1
                
#         ppgmap[ind,:,0]=subregions_r
#         ppgmap[ind,:,1]=subregions_b
#         ppgmap[ind,:,2]=subregions_g       
#         ppgmap[ind,:,3]=subregions_y
#         ppgmap[ind,:,4]=subregions_v
#         #print(ppgmap[ind])
#         ind+=1
#         frame_count += 1
#         #curr_seg.append(frame)
#         #print(ppgmap[ind])
#         if frame_count == frames_per_segment:
#             vidnum=vid_num[:3]
#             min_values = np.min(ppgmap, axis=(0, 1))
#             max_values = np.max(ppgmap, axis=(0, 1))
#             # print(min_values.shape)
#             scaled_data = ((ppgmap - min_values) / (max_values - min_values) * 255.0).astype(np.uint8)
#             #cv2.imwrite(f'{outpath}/{vidnum}_{segment_number}.png',scaled_data)
#             np.save(f'{vidnum}_{segment_number}.npy',scaled_data)
#             segment_number += 1
#             ppgmap=np.empty([128,32,5])
#             ind=0
#             frame_count = 0
#     cap.release()
#     print(vid_path," completed.")

# %%
# create_ppg_maps(r"C:\Users\hites\Downloads\deepfake-detection-challenge\train_sample_videos\errocgcham.mp4","errocgcham.mp4")
